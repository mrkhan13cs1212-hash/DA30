# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv

file_path = "/content/drive/MyDrive/Colab Notebooks/Day02/students.csv"
with open(file_path, "r") as file:
    reader = csv.reader(file)

    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'Marks']
# ['Rahul', '20', '85']
# ['Anita', '21', '91']
# ['Ravi', '19', '78']
# ['Priya', '20', '88']

# %%
import csv

file_path = "/content/drive/MyDrive/Colab Notebooks/Day02/students.csv"

students = []
total_marks = 0
highest_marks = -1
highest_scorer = ""

with open(file_path, "r") as file:
    reader = csv.DictReader(file)

    for row in reader:
        marks = float(row["Marks"])

        students.append(row)
        total_marks += marks

        # Find highest scorer
        if marks > highest_marks:
            highest_marks = marks
            highest_scorer = row["Name"]

# Calculate average
average = total_marks / len(students)

print("Average Marks:", average)
print("Highest Scorer:", highest_scorer)
print("Highest Marks:", highest_marks)

print("\nStudents Scoring Above 80:")
for student in students:
    if float(student["Marks"]) > 80:
        print(f"{student['Name']} ({student['Marks']})")
# Out:
# Average Marks: 85.5
# Highest Scorer: Anita
# Highest Marks: 91.0
#
# Students Scoring Above 80:
# Rahul (85)
# Anita (91)
# Priya (88)
