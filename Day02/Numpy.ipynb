# %%
pip install numpy

# %%
import numpy as np

marks = np.array([85, 91, 78, 88])

print("Average:", np.mean(marks))
print("Maximum:", np.max(marks))
print("Minimum:", np.min(marks))
# Out:
# Average: 85.5
# Maximum: 91
# Minimum: 78
